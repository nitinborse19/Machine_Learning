# %%
#importing dataset
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os

# %%
os.chdir(r'C:\Users\ROHAN\Downloads')

# %%
df= pd.read_csv('rainfall_combined.csv')
df
# Out:
#          ID            UT  year  month  day      time  raingauges_id  \
# 0         1  1.512227e+09  2017     12    2  15:05:00              1
# 1         2  1.512227e+09  2017     12    2  15:10:00              1
# 2         3  1.512228e+09  2017     12    2  15:15:00              1
# 3         4  1.512228e+09  2017     12    2  15:20:00              1
# 4         5  1.512252e+09  2017     12    2  22:00:00              1
# ...     ...           ...   ...    ...  ...       ...            ...
# 6744  80001           NaN  2017     12    2  22:00:00             43
# 6745  80002           NaN  2017     12    3  22:00:00             43
# 6746  80003           NaN  2017     12    4  22:00:00             43
# 6747  80004           NaN  2017     12    5  22:00:00             43
# 6748  80005           NaN  2017     12    6  22:00:00             43
#
#                 name  ward_id    region  data
# 0     BLUFF RES NO.3     66.0   Central   0.6
# ...

# %%
#check the null values
df.isnull().sum()
# Out:
# ID               0
# UT               5
# year             0
# month            0
# day              0
# time             0
# raingauges_id    0
# name             0
# ward_id          5
# region           0
# data             5
# dtype: int64

# %%
#fill the null values using fillna
df.fillna(value=df['UT'].median(),inplace=True)
df.fillna(value=df['ward_id'].median(),inplace=True)
df.fillna(value=df['data'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# ID               0
# UT               0
# year             0
# month            0
# day              0
# time             0
# raingauges_id    0
# name             0
# ward_id          0
# region           0
# data             0
# dtype: int64

# %%
#to check the mean, median.
df.describe()
# Out:
#                  ID            UT    year   month          day  raingauges_id  \
# count   6749.000000  6.749000e+03  6749.0  6749.0  6749.000000    6749.000000
# mean   17995.661135  1.512504e+09  2017.0    12.0     5.285079      20.814195
# std    16004.920032  6.554381e+04     0.0     0.0     0.906041      12.523333
# min        1.000000  1.512169e+09  2017.0    12.0     1.000000       1.000000
# 25%     6600.000000  1.512494e+09  2017.0    12.0     5.000000      10.000000
# 50%    14462.000000  1.512518e+09  2017.0    12.0     6.000000      19.000000
# 75%    22588.000000  1.512541e+09  2017.0    12.0     6.000000      32.000000
# max    80005.000000  1.512637e+09  2017.0    12.0     7.000000      44.000000
#
#             ward_id          data
# count  6.749000e+03  6.749000e+03
# mean   1.120594e+06  1.120550e+06
# std    4.115638e+07  4.115638e+07
# min    1.000000e+00  0.000000e+00
# 25%    1.800000e+01  2.000000e-01
# 50%    3.500000e+01  2.000000e-01
# ...

# %%
#to check the info about the data and here we can check the data type of features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6749 entries, 0 to 6748
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             6749 non-null   int64
#  1   UT             6749 non-null   float64
#  2   year           6749 non-null   int64
#  3   month          6749 non-null   int64
#  4   day            6749 non-null   int64
#  5   time           6749 non-null   object
#  6   raingauges_id  6749 non-null   int64
#  7   name           6749 non-null   object
#  8   ward_id        6749 non-null   float64
#  9   region         6749 non-null   object
#  10  data           6749 non-null   float64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 580.1+ KB

# %%
#using this we can convert the 
df['time']=pd.to_datetime(df['time'])

# %%
df['name'] = pd.get_dummies(df['name'],drop_first = True)

# %%
#to check the data type and info the given dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6749 entries, 0 to 6748
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             6749 non-null   int64
#  1   UT             6749 non-null   float64
#  2   year           6749 non-null   int64
#  3   month          6749 non-null   int64
#  4   day            6749 non-null   int64
#  5   time           6749 non-null   datetime64[ns]
#  6   raingauges_id  6749 non-null   int64
#  7   name           6749 non-null   uint8
#  8   ward_id        6749 non-null   float64
#  9   region         6749 non-null   object
#  10  data           6749 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(5), object(1), uint8(1)
# memory usage: 534.0+ KB

# %%
df.shape
# Out:
# (6749, 11)

# %%
sns.boxplot('raingauges_id','ID',data=df)

# %%
sns.pairplot(df)

# %%
sns.barplot("region",'raingauges_id', data=df)
