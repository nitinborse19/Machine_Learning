# %%
# Feature scaling
#Rescaling (min-max normalization)
#[0,1]=x-xmin/xmax-xmin
#[a,b]=a+(x-xmin)*(b-a)/Xmax-Xmin
#standardization(Z-scale normalization)

# %%
# rescaling(min-max normalization)
import numpy as np
data=np.array([1.4,3.4,5.6,2.3])
print(data)
# Out:
# [1.4 3.4 5.6 2.3]

# %%
dmin=np.min(data)
dmax=np.max(data)

# %%
# X-Xmin/Xmax-Xmin                            its possible bcoz of numpy array
print((data-dmin)/(dmax-dmin))
# Out:
# [0.         0.47619048 1.         0.21428571]

# %%
data=data.reshape(-1,1)            # -1 is row and 1 is column
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
m.fit(data)
print(m.transform(data))
# Out:
# [[0.        ]
#  [0.47619048]
#  [1.        ]
#  [0.21428571]]

# %%
data=np.array([1.4,3.4,2.3,5.6])
#[a,b]
a=4.6
b=8.6
dmin=np.min(data)
print(dmin)
dmax=np.max(data)
print(dmax)
#a+(data-dmin)*(b-a)/(dmax-dmin)
print(a+(data-dmin)*(b-a)/(dmax-dmin))
# Out:
# 1.4
# 5.6
# [4.6        6.5047619  5.45714286 8.6       ]

# %%
data=data.reshape(-1,1)
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler(feature_range=(a,b))
m.fit(data)
print(m.transform(data))
# Out:
# [[4.6       ]
#  [6.5047619 ]
#  [8.6       ]
#  [5.45714286]]

# %%
print(a+(data-dmin)*0.9523809523809526)
# Out:
# [4.6        6.5047619  5.45714286 8.6       ]

# %%
print((b-a)/(dmax-dmin))
# Out:
# 0.9523809523809526

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(data=df)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Krishna\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sns.boxplot(x="petal_width",y="petal_length",data=df)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Krishna\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
b=df.loc[:,"sepal_length"]
print(b)
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
data1=np.array([b])
print(data1)
# Out:
# [[5.1 4.9 4.7 4.6 5.  5.4 4.6 5.  4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#   5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.  5.  5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.
#   5.5 4.9 4.4 5.1 5.  4.5 4.4 5.  5.1 4.8 5.1 4.6 5.3 5.  7.  6.4 6.9 5.5
#   6.5 5.7 6.3 4.9 6.6 5.2 5.  5.9 6.  6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
#   6.3 6.1 6.4 6.6 6.8 6.7 6.  5.7 5.5 5.5 5.8 6.  5.4 6.  6.7 6.3 5.6 5.5
#   5.5 6.1 5.8 5.  5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1 6.3 6.5 7.6 4.9 7.3
#   6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.  6.9 5.6 7.7 6.3 6.7 7.2
#   6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.  6.9 6.7 6.9 5.8 6.8
#   6.7 6.7 6.3 6.5 6.2 5.9]]

# %%
dmin=np.min(data1)
print(dmin)
dmax=np.max(data1)
print(dmax)
# Out:
# 4.3
# 7.9

# %%
print((data1-dmin)/(dmax-dmin))
# Out:
# [[0.22222222 0.16666667 0.11111111 0.08333333 0.19444444 0.30555556
#   0.08333333 0.19444444 0.02777778 0.16666667 0.30555556 0.13888889
#   0.13888889 0.         0.41666667 0.38888889 0.30555556 0.22222222
#   0.38888889 0.22222222 0.30555556 0.22222222 0.08333333 0.22222222
#   0.13888889 0.19444444 0.19444444 0.25       0.25       0.11111111
#   0.13888889 0.30555556 0.25       0.33333333 0.16666667 0.19444444
#   0.33333333 0.16666667 0.02777778 0.22222222 0.19444444 0.05555556
#   0.02777778 0.19444444 0.22222222 0.13888889 0.22222222 0.08333333
#   0.27777778 0.19444444 0.75       0.58333333 0.72222222 0.33333333
#   0.61111111 0.38888889 0.55555556 0.16666667 0.63888889 0.25
#   0.19444444 0.44444444 0.47222222 0.5        0.36111111 0.66666667
#   0.36111111 0.41666667 0.52777778 0.36111111 0.44444444 0.5
#   0.55555556 0.5        0.58333333 0.63888889 0.69444444 0.66666667
#   0.47222222 0.38888889 0.33333333 0.33333333 0.41666667 0.47222222
# ...

# %%
data1=data1.reshape(-1,1)            # -1 is row and 1 is column
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
m.fit(data1)
x=(m.transform(data1))
print(x)
# Out:
# [[0.22222222]
#  [0.16666667]
#  [0.11111111]
#  [0.08333333]
#  [0.19444444]
#  [0.30555556]
#  [0.08333333]
#  [0.19444444]
#  [0.02777778]
#  [0.16666667]
#  [0.30555556]
#  [0.13888889]
#  [0.13888889]
#  [0.        ]
#  [0.41666667]
#  [0.38888889]
#  [0.30555556]
#  [0.22222222]
#  [0.38888889]
#  [0.22222222]
#  [0.30555556]
#  [0.22222222]
#  [0.08333333]
#  [0.22222222]
#  [0.13888889]
#  [0.19444444]
#  [0.19444444]
#  [0.25      ]
#  [0.25      ]
#  [0.11111111]
#  [0.13888889]
#  [0.30555556]
#  [0.25      ]
#  [0.33333333]
#  [0.16666667]
#  [0.19444444]
#  [0.33333333]
#  [0.16666667]
#  [0.02777778]
#  [0.22222222]
#  [0.19444444]
#  [0.05555556]
#  [0.02777778]
#  [0.19444444]
#  [0.22222222]
#  [0.13888889]
#  [0.22222222]
#  [0.08333333]
#  [0.27777778]
#  [0.19444444]
#  [0.75      ]
#  [0.58333333]
#  [0.72222222]
#  [0.33333333]
#  [0.61111111]
#  [0.38888889]
#  [0.55555556]
#  [0.16666667]
#  [0.63888889]
#  [0.25      ]
#  [0.19444444]
#  [0.44444444]
# ...

# %%
sns.boxplot(data=x)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Krishna\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
c=df.loc[:,"sepal_width"]
print(c)
data2=np.array([c])
print(data2)
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64
# [[3.5 3.  3.2 3.1 3.6 3.9 3.4 3.4 2.9 3.1 3.7 3.4 3.  3.  4.  4.4 3.9 3.5
#   3.8 3.8 3.4 3.7 3.6 3.3 3.4 3.  3.4 3.5 3.4 3.2 3.1 3.4 4.1 4.2 3.1 3.2
#   3.5 3.6 3.  3.4 3.5 2.3 3.2 3.5 3.8 3.  3.8 3.2 3.7 3.3 3.2 3.2 3.1 2.3
#   2.8 2.8 3.3 2.4 2.9 2.7 2.  3.  2.2 2.9 2.9 3.1 3.  2.7 2.2 2.5 3.2 2.8
#   2.5 2.8 2.9 3.  2.8 3.  2.9 2.6 2.4 2.4 2.7 2.7 3.  3.4 3.1 2.3 3.  2.5
#   2.6 3.  2.6 2.3 2.7 3.  2.9 2.9 2.5 2.8 3.3 2.7 3.  2.9 3.  3.  2.5 2.9
#   2.5 3.6 3.2 2.7 3.  2.5 2.8 3.2 3.  3.8 2.6 2.2 3.2 2.8 2.8 2.7 3.3 3.2
#   2.8 3.  2.8 3.  2.8 3.8 2.8 2.8 2.6 3.  3.4 3.1 3.  3.1 3.1 3.1 2.7 3.2
#   3.3 3.  2.5 3.  3.4 3. ]]

# %%
dmin=np.min(data2)
print(dmin)
dmax=np.max(data2)
print(dmax)
# Out:
# 2.0
# 4.4

# %%
data2=data2.reshape(-1,1)            # -1 is row and 1 is column
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
m.fit(data2)
y=(m.transform(data2))
print(y)
# Out:
# [[0.625     ]
#  [0.41666667]
#  [0.5       ]
#  [0.45833333]
#  [0.66666667]
#  [0.79166667]
#  [0.58333333]
#  [0.58333333]
#  [0.375     ]
#  [0.45833333]
#  [0.70833333]
#  [0.58333333]
#  [0.41666667]
#  [0.41666667]
#  [0.83333333]
#  [1.        ]
#  [0.79166667]
#  [0.625     ]
#  [0.75      ]
#  [0.75      ]
#  [0.58333333]
#  [0.70833333]
#  [0.66666667]
#  [0.54166667]
#  [0.58333333]
#  [0.41666667]
#  [0.58333333]
#  [0.625     ]
#  [0.58333333]
#  [0.5       ]
#  [0.45833333]
#  [0.58333333]
#  [0.875     ]
#  [0.91666667]
#  [0.45833333]
#  [0.5       ]
#  [0.625     ]
#  [0.66666667]
#  [0.41666667]
#  [0.58333333]
#  [0.625     ]
#  [0.125     ]
#  [0.5       ]
#  [0.625     ]
#  [0.75      ]
#  [0.41666667]
#  [0.75      ]
#  [0.5       ]
#  [0.70833333]
#  [0.54166667]
#  [0.5       ]
#  [0.5       ]
#  [0.45833333]
#  [0.125     ]
#  [0.33333333]
#  [0.33333333]
#  [0.54166667]
#  [0.16666667]
#  [0.375     ]
#  [0.29166667]
#  [0.        ]
#  [0.41666667]
# ...

# %%
sns.boxplot(data=y)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Krishna\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("iris")
df=df.drop(columns=["species"])
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
sns.boxplot(data=df)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Krishna\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
m=MinMaxScaler()
m.fit(df)
scale_df=m.transform(df)
sns.boxplot(data=scale_df)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Krishna\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
scale_df=m.fit_transform(df)
print(scale_df)
# Out:
# [[0.22222222 0.625      0.06779661 0.04166667]
#  [0.16666667 0.41666667 0.06779661 0.04166667]
#  [0.11111111 0.5        0.05084746 0.04166667]
#  [0.08333333 0.45833333 0.08474576 0.04166667]
#  [0.19444444 0.66666667 0.06779661 0.04166667]
#  [0.30555556 0.79166667 0.11864407 0.125     ]
#  [0.08333333 0.58333333 0.06779661 0.08333333]
#  [0.19444444 0.58333333 0.08474576 0.04166667]
#  [0.02777778 0.375      0.06779661 0.04166667]
#  [0.16666667 0.45833333 0.08474576 0.        ]
#  [0.30555556 0.70833333 0.08474576 0.04166667]
#  [0.13888889 0.58333333 0.10169492 0.04166667]
#  [0.13888889 0.41666667 0.06779661 0.        ]
#  [0.         0.41666667 0.01694915 0.        ]
#  [0.41666667 0.83333333 0.03389831 0.04166667]
#  [0.38888889 1.         0.08474576 0.125     ]
#  [0.30555556 0.79166667 0.05084746 0.125     ]
#  [0.22222222 0.625      0.06779661 0.08333333]
#  [0.38888889 0.75       0.11864407 0.08333333]
#  [0.22222222 0.75       0.08474576 0.08333333]
# ...

# %% [markdown]
# # Standardization

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
data=np.array([1.3,2.1,4.5,6.5])
print("Before scaling")
print(data)
mean=np.mean(data)
std=np.std(data)
print(np.mean(data))
print(np.std(data))
#data-mean/std
scaled_data=(data-mean)/std
print("after scaling")
print(scaled_data)
print(np.mean(scaled_data))
print(np.std(scaled_data))
# Out:
# Before scaling
# [1.3 2.1 4.5 6.5]
# 3.6
# 2.046948949045872
# after scaling
# [-1.12362353 -0.73279795  0.43967877  1.41674271]
# 0.0
# 0.9999999999999999

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
data=np.array([1.3,2.1,4.5,6.5])
data=data.reshape(-1,1)            # -1 is row and 1 is column
m=StandardScaler()
print(m.fit(data))
scaled_data=(data-mean)/std
print(m.transform(data))
print(np.mean(scaled_data))
print(np.std(scaled_data))
# Out:
# StandardScaler()
# [[-1.12362353]
#  [-0.73279795]
#  [ 0.43967877]
#  [ 1.41674271]]
# 0.0
# 0.9999999999999999

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
data=np.array([1.3,2.1,4.5,6.5])
data=data.reshape(-1,1)            # -1 is row and 1 is column
m=StandardScaler()
m.fit(data)
sc_data=m.transform(data)
print(np.mean(sc_data))
print(np.std(sc_data))
#fit_transform
sc_data1=m.fit_transform(data)
print(np.mean(sc_data1))
print(np.std(sc_data1))
# Out:
# 0.0
# 0.9999999999999999
# 0.0
# 0.9999999999999999

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
df=pd.read_csv("C:\\Users\\Krishna\\Desktop\\dataset\\Bodyfat_1.csv")
df
# Out:
#      Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
s=MinMaxScaler()
s.fit(df)
scale_df=s.transform(df)
print(scale_df)
print(np.mean(scale_df))
print(np.std(scale_df))
print(np.max(scale_df))
print(np.min(scale_df))
# Out:
# [[0.66549605 0.25894737 0.01694915 ... 0.35643564 0.46043165 0.23214286]
#  [0.7928007  0.12842105 0.         ... 0.28217822 0.56834532 0.42857143]
#  [0.40737489 0.53263158 0.         ... 0.1980198  0.30215827 0.14285714]
#  ...
#  [0.33187006 0.61684211 0.84745763 ... 0.32178218 0.44604317 0.39285714]
#  [0.39420544 0.54736842 0.84745763 ... 0.28217822 0.60431655 0.71428571]
#  [0.28182616 0.67157895 0.88135593 ... 0.44059406 0.64748201 0.91071429]]
# 0.3961800913974409
# 0.20774142622659675
# 1.0000000000000002
# 0.0

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
s.fit(df)
scale_df1=s.transform(df)
print(scale_df1)
print(np.mean(scale_df1))
print(np.std(scale_df1))
print(np.max(scale_df))
print(np.min(scale_df))
# Out:
# [[ 0.80164696 -0.82024615 -1.74007329 ... -0.09067593 -0.62671828
#   -1.2125412 ]
#  [ 1.56506057 -1.56257271 -1.81958344 ... -0.58814329  0.11707924
#   -0.0319426 ]
#  [-0.74623993  0.73624504 -1.81958344 ... -1.15193963 -1.71762131
#   -1.74917692]
#  ...
#  [-1.19902317  1.2151654   2.15592399 ... -0.32282736 -0.72589128
#   -0.24659689]
#  [-0.82521375  0.8200561   2.15592399 ... -0.58814329  0.36501175
#    1.68529172]
#  [-1.49912369  1.52646364  2.31494429 ...  0.47312041  0.66253075
#    2.86589032]]
# 3.905165432649757e-16
# 1.0
# 1.0000000000000002
# 0.0

# %%
a=np.array(scale_df1)

# %%
a
# Out:
# array([[ 0.80164696, -0.82024615, -1.74007329, ..., -0.09067593,
#         -0.62671828, -1.2125412 ],
#        [ 1.56506057, -1.56257271, -1.81958344, ..., -0.58814329,
#          0.11707924, -0.0319426 ],
#        [-0.74623993,  0.73624504, -1.81958344, ..., -1.15193963,
#         -1.71762131, -1.74917692],
#        ...,
#        [-1.19902317,  1.2151654 ,  2.15592399, ..., -0.32282736,
#         -0.72589128, -0.24659689],
#        [-0.82521375,  0.8200561 ,  2.15592399, ..., -0.58814329,
#          0.36501175,  1.68529172],
#        [-1.49912369,  1.52646364,  2.31494429, ...,  0.47312041,
#          0.66253075,  2.86589032]])

# %%
b=pd.DataFrame(a)

# %%
b
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.801647 -0.820246 -1.740073 -0.841246 -0.656205 -0.738665 -0.918048
# 1    1.565061 -1.562573 -1.819583 -0.193462  0.574790  0.209365 -0.858621
# 2   -0.746240  0.736245 -1.819583 -0.849769 -1.066536 -1.645475 -0.597144
# 3    1.028039 -1.047733 -1.501543  0.198617  0.574790 -0.244041  0.115976
# 4   -1.135844  1.143327 -1.660563  0.181570  0.301235 -1.480601 -0.418864
# ..        ...       ...       ...       ...       ...       ...       ...
# 247  0.949065 -0.975895  1.996904 -1.523123 -0.861370 -1.274507 -1.381576
# 248 -1.683396  1.730005  2.155924  0.752642 -0.109096  1.198613  0.912294
# 249 -1.199023  1.215165  2.155924  0.266805 -1.134925  0.374239  1.221312
# 250 -0.825214  0.820056  2.155924  0.403180  0.096070  0.374239  0.888523
# 251 -1.499124  1.526464  2.314944  0.974252 -0.040707  1.157394  1.375822
#
#             7         8         9        10        11        12        13  \
# ...
