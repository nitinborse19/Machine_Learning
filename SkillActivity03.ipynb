# %% [raw]
#                                             SKILL ACTIVITY NO: 3
# Name: Nitin Jayvant Borse                                                                                               Date:24-3-2021
# PRN:1712206
# School: School of Data Science
# Program: Machine Learning and AI Analyst
# Batch: ML6
# Module Name: Python Programming
# Module Code: ML06
#
# #### Title: Skill Activity 1
#
# Skills/Competencies to be acquired:
# To gain an understanding of data and find clues from the data.
# Assess assumptions on which statistical inference will be based.
# To check the quality of data for further processing and cleaning if necessary.
# To check for anomalies or outliers that may impact model.
# Data Visualization.
# Duration of activity: 2 Hour
#
# 1.What is the purpose of this activity?
# Preview data.
# Check total number of entries and column types.
# Check any null values.
# Check duplicate entries.
# Plot distribution of numeric data (univariate and pairwise joint distribution).
# Plot count distribution of categorical data.
#
#
# 2.Steps performed in this activity.
# 1)Import Necessary Libraries.
# 2)Read .csv Datafile.
# 3)Perform Array operation.
# 4)Perform Pandas Dataframe operation.
# 5)Data cleaning
# 6)Plot Histogram
#
# 3.What resources / materials / equipment / tools did you use for this activity?
# 1)Jupyter Notebook.
# 2).CSV File
# 3)python 3.8
# 4)Machine Learning Libraries.
#
# 4.What skills did you acquire?
# 1)How to Pandas Library work
# 2)How to read .csv file
# 3)working on different Dataset
# 4)ML Libraries working
#
# 5.Time taken to complete the activity?
# 1)Total time taken to complete Skill activity=120 min (2hour)

# %%
##Import Necessary Libraries
import math
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # 1. Arrays

# %% [markdown]
# Question 1.1 Use np.arange to create an array with the multiples of 99 from 0 up to (and including) 9999. (So its elements are 0, 99, 198, 297, etc.)

# %%
a=np.arange(0,10000,99)
print(a)
# Out:
# [   0   99  198  297  396  495  594  693  792  891  990 1089 1188 1287
#  1386 1485 1584 1683 1782 1881 1980 2079 2178 2277 2376 2475 2574 2673
#  2772 2871 2970 3069 3168 3267 3366 3465 3564 3663 3762 3861 3960 4059
#  4158 4257 4356 4455 4554 4653 4752 4851 4950 5049 5148 5247 5346 5445
#  5544 5643 5742 5841 5940 6039 6138 6237 6336 6435 6534 6633 6732 6831
#  6930 7029 7128 7227 7326 7425 7524 7623 7722 7821 7920 8019 8118 8217
#  8316 8415 8514 8613 8712 8811 8910 9009 9108 9207 9306 9405 9504 9603
#  9702 9801 9900 9999]

# %% [markdown]
# Question 1.2. Create an array of the time, in seconds, since the start of the month at which each hourly reading was taken. Name it collection_times.

# %%
collection_times=np.arange(0,44640,60)
print(collection_times)
len(collection_times)
# Out:
# [    0    60   120   180   240   300   360   420   480   540   600   660
#    720   780   840   900   960  1020  1080  1140  1200  1260  1320  1380
#   1440  1500  1560  1620  1680  1740  1800  1860  1920  1980  2040  2100
#   2160  2220  2280  2340  2400  2460  2520  2580  2640  2700  2760  2820
#   2880  2940  3000  3060  3120  3180  3240  3300  3360  3420  3480  3540
#   3600  3660  3720  3780  3840  3900  3960  4020  4080  4140  4200  4260
#   4320  4380  4440  4500  4560  4620  4680  4740  4800  4860  4920  4980
#   5040  5100  5160  5220  5280  5340  5400  5460  5520  5580  5640  5700
#   5760  5820  5880  5940  6000  6060  6120  6180  6240  6300  6360  6420
#   6480  6540  6600  6660  6720  6780  6840  6900  6960  7020  7080  7140
#   7200  7260  7320  7380  7440  7500  7560  7620  7680  7740  7800  7860
#   7920  7980  8040  8100  8160  8220  8280  8340  8400  8460  8520  8580
#   8640  8700  8760  8820  8880  8940  9000  9060  9120  9180  9240  9300
# ...

# %% [markdown]
# Question 1.3 The powers of 2 ( 20=1 ,  21=2 ,  22=4 , etc) arise frequently in computer science. (For example, you may have noticed that storage on smartphones or USBs come in powers of 2, like 16 GB, 32 GB, or 64 GB.) Use np.arange and the exponentiation operator ** to compute the first 30 powers of 2, starting from 2^0.

# %%
pwr=2**np.arange(30)
pwr
# Out:
# array([        1,         2,         4,         8,        16,        32,
#               64,       128,       256,       512,      1024,      2048,
#             4096,      8192,     16384,     32768,     65536,    131072,
#           262144,    524288,   1048576,   2097152,   4194304,   8388608,
#         16777216,  33554432,  67108864, 134217728, 268435456, 536870912],
#       dtype=int32)

# %% [markdown]
# Question 1.4 Get all items between 5 and 10 from a.

# %%
a = np.array([2, 6, 1, 9, 10, 3, 27])
print(a)
a[(a >= 5) & (a <= 10)]
# Out:
# [ 2  6  1  9 10  3 27]
# array([ 6,  9, 10])

# %% [markdown]
# Question 1.5 Create the following pattern without hardcoding. Use only numpy functions and the below input array a.

# %%
a = np.array([1,2,3])
a
np.r_[np.repeat(a, 3),np.tile(a,3)]
# Out:
# array([1, 1, 1, 2, 2, 2, 3, 3, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3])

# %% [markdown]
# # 2. Pandas DataFrames

# %% [markdown]
# Question 2.1 In the cell below, we've created 2 arrays. Using the steps above, assign top_10_movies to a DataFrame that has two columns called "Rating" and "Name", which hold top_10_movie_ratings and top_10_movie_names respectively.

# %%
top_10_movie_ratings = np.array([9.2, 9.2, 9., 8.9, 8.9, 8.9, 8.9, 8.9, 8.9, 8.8])
top_10_movie_names = np.array([
        'The Shawshank Redemption (1994)',
        'The Godfather (1972)',
        'The Godfather: Part II (1974)',
        'Pulp Fiction (1994)',
        "Schindler's List (1993)",
        'The Lord of the Rings: The Return of the King (2003)',
        '12 Angry Men (1957)',
        'The Dark Knight (2008)',
        'Il buono, il brutto, il cattivo (1966)',
        'The Lord of the Rings: The Fellowship of the Ring (2001)'
])

top_10_movies=pd.DataFrame()
top_10_movies["Rating"]=top_10_movie_ratings
top_10_movies["Name"]=top_10_movie_names
top_10_movies
# Out:
#    Rating                                               Name
# 0     9.2                    The Shawshank Redemption (1994)
# 1     9.2                               The Godfather (1972)
# 2     9.0                      The Godfather: Part II (1974)
# 3     8.9                                Pulp Fiction (1994)
# 4     8.9                            Schindler's List (1993)
# 5     8.9  The Lord of the Rings: The Return of the King ...
# 6     8.9                                12 Angry Men (1957)
# 7     8.9                             The Dark Knight (2008)
# 8     8.9             Il buono, il brutto, il cattivo (1966)
# 9     8.8  The Lord of the Rings: The Fellowship of the R...

# %% [markdown]
# Question 2.2 Create a new DataFrame called with_ranking by adding a column named "Ranking" to the table in top_10_movies.

# %%
my_ranking = [8, 2, 1, 9, 7, 10, 6, 4, 3, 5]
with_ranking=pd.DataFrame()
with_ranking["Rating"]=top_10_movie_ratings
with_ranking["Name"]=top_10_movie_names
with_ranking["Ranking"]=my_ranking
with_ranking
# Out:
#    Rating                                               Name  Ranking
# 0     9.2                    The Shawshank Redemption (1994)        8
# 1     9.2                               The Godfather (1972)        2
# 2     9.0                      The Godfather: Part II (1974)        1
# 3     8.9                                Pulp Fiction (1994)        9
# 4     8.9                            Schindler's List (1993)        7
# 5     8.9  The Lord of the Rings: The Return of the King ...       10
# 6     8.9                                12 Angry Men (1957)        6
# 7     8.9                             The Dark Knight (2008)        4
# 8     8.9             Il buono, il brutto, il cattivo (1966)        3
# 9     8.8  The Lord of the Rings: The Fellowship of the R...        5

# %% [markdown]
# # Functions and CEO Incomes

# %%
raw_compensation = pd.read_csv("C:\\Users\\Omkar\\Downloads\\Datasets\\california-ceo-compensation.csv").set_index('Rank')
raw_compensation
# Out:
#                        Name                           Company (Headquarters)  \
# Rank
# 1             Mark V. Hurd*                            Oracle (Redwood City)
# 2            Safra A. Catz*                            Oracle (Redwood City)
# 3            Robert A. Iger                            Walt Disney (Burbank)
# 4          Marissa A. Mayer                               Yahoo! (Sunnyvale)
# 5              Marc Benioff                   salesforce.com (San Francisco)
# 6        John H. Hammergren                         McKesson (San Francisco)
# 7            John S. Watson                              Chevron (San Ramon)
# 8            Jeffrey Weiner                         LinkedIn (Mountain View)
# 9        John T. Chambers**                         Cisco Systems (San Jose)
# 10           John G. Stumpf                     Wells Fargo  (San Francisco)
# 11         John C. Martin**                    Gilead Sciences (Foster City)
# ...

# %% [markdown]
# Question 2.3 You should have found that the values in "Total Pay" column are strings (text). It doesn't make sense to take the average of the text values, so we need to convert them to numbers if we want to do this. Extract the first value in the "Total Pay" column. It's Mark Hurd's pay in 2015, in millions of dollars. Call it mark_hurd_pay_string.

# %%
mark_hurd_pay_string=raw_compensation.iloc[0,2]
a=mark_hurd_pay_string
print(a)
# Out:
# $53.25

# %% [markdown]
# Question 2.3.1 Using code, mark_hurd_pay_string to a number of dollars.

# %%
a.split()
# Out:
# ['$53.25']

# %% [markdown]
# Question 2.3.3 Using apply, make a Daatframe that's a copy of raw_compensation with one more column called "Total_Pay_Dollars". It should be the result of applying convert_pay_string_to_number to the "Total Pay" column, as we did above. Call the new df compensation

# %%
def getpayinnum(b):
    y=float(b.split("$")[1])*10**6    
    return y
raw_compensation["ToTal_Pay_Dollars"]=raw_compensation["Total Pay"].apply(getpayinnum)
new_df_compensation=pd.DataFrame(raw_compensation)
new_df_compensation
# Out:
#                        Name                           Company (Headquarters)  \
# Rank
# 1             Mark V. Hurd*                            Oracle (Redwood City)
# 2            Safra A. Catz*                            Oracle (Redwood City)
# 3            Robert A. Iger                            Walt Disney (Burbank)
# 4          Marissa A. Mayer                               Yahoo! (Sunnyvale)
# 5              Marc Benioff                   salesforce.com (San Francisco)
# 6        John H. Hammergren                         McKesson (San Francisco)
# 7            John S. Watson                              Chevron (San Ramon)
# 8            Jeffrey Weiner                         LinkedIn (Mountain View)
# 9        John T. Chambers**                         Cisco Systems (San Jose)
# 10           John G. Stumpf                     Wells Fargo  (San Francisco)
# 11         John C. Martin**                    Gilead Sciences (Foster City)
# ...

# %% [markdown]
# # 3. Data Cleaning

# %%
gfm_data = pd.read_csv('C:\\Users\\Omkar\\Downloads\\Datasets\\gfm_data.csv')
gfm_data
# Out:
#     Category                                              Title  \
# 0    Medical                            Justice for Jacob Blake
# 1    Medical        Official Navajo Nation COVID-19 Relief Fund
# 2    Medical   Help a front line nurse and baby get proper care
# 3    Medical                 Rest up, Tommy, we'll see you soon
# 4    Medical                OFFICIAL BRANDON SAENZ MEDICAL FUND
# 5    Medical  Helping Laura and Katherine get through my death.
# 6    Medical                  Help Mattress Mack Save Camp Hope
# 7    Medical                                   Rise Up for Rhys
# 8    Medical                       COVID-19 Protest Relief Fund
# 9    Medical                                   The Nolan Family
# 10   Medical        Support Chelsea Ellis's Mission To Recovery
# 11   Medical           PLEASE HELP ME IN THE BATTLE FOR MY LIFE
# 12   Medical       Food for Disaster Victims of Beirut, Lebanon
# 13   Medical  Help to save Mrs. Satya Ponna-wife of Priest P...
# ...

# %% [markdown]
# Question 3.1.1 Define a function named convert_units which converts a string representation of a number to an integer. This function should work whether or not the string representation has a ‘K’ in it (representing thousands).

# %%
def getconvert_units(string_rep):
        x=(string_rep).isdigit()
        if x==True:
            return float(string_rep)
        else:
            y=float(string_rep.split("K")[0])*1000
            return y

# %% [markdown]
# Question 3.1.2. Overwrite the columns for Number_of_Donors and FB_Shares with columns of the same name, but containing integers instead of strings. The dataframe should still be named gfm_data.

# %%
gfm_data["Number_of_Donors"]=gfm_data["Number_of_Donors"].apply(getconvert_units)
print(gfm_data["Number_of_Donors"])
# Out:
# 0      72500.0
# 1      21900.0
# 2      18300.0
# 3      10300.0
# 4      24300.0
# 5       9700.0
# 6        188.0
# 7       3100.0
# 8       7500.0
# 9       5500.0
# 10      2700.0
# 11      7800.0
# 12      4100.0
# 13      5600.0
# 14     10400.0
# 15     10800.0
# 16      3100.0
# 17       867.0
# 18      3800.0
# 19      8200.0
# 20      1900.0
# 21       968.0
# 22      7700.0
# 23      3000.0
# 24      1700.0
# 25      1300.0
# 26      1200.0
# 27      1500.0
# 28      3800.0
# 29      1100.0
#         ...
# 808      320.0
# 809      272.0
# 810      348.0
# 811     1000.0
# 812      431.0
# 813      588.0
# 814      177.0
# 815      341.0
# 816      623.0
# 817      206.0
# 818      131.0
# 819      126.0
# 820      572.0
# 821      210.0
# 822      648.0
# 823      115.0
# 824      215.0
# 825      123.0
# 826      188.0
# 827      479.0
# 828      457.0
# 829       64.0
# 830       60.0
# 831      234.0
# 832      896.0
# 833      366.0
# 834      279.0
# 835      318.0
# ...

# %%
gfm_data["FB_Shares"]=gfm_data["FB_Shares"].apply(getconvert_units)
print(gfm_data["FB_Shares"])
# Out:
# 0      118000.0
# 1       71700.0
# 2       16400.0
# 3       21300.0
# 4        5500.0
# 5        1500.0
# 6          84.0
# 7        2300.0
# 8        6600.0
# 9       47700.0
# 10      10900.0
# 11       6700.0
# 12       1600.0
# 13       1100.0
# 14      35800.0
# 15       1300.0
# 16       8400.0
# 17       1700.0
# 18      14400.0
# 19      50800.0
# 20       4300.0
# 21        658.0
# 22      13200.0
# 23       2200.0
# 24       2800.0
# 25       1400.0
# 26       5600.0
# 27       7600.0
# 28      19500.0
# 29       1700.0
#          ...
# 808       779.0
# 809      2600.0
# 810      1700.0
# 811        50.0
# 812      2900.0
# 813         8.0
# 814       495.0
# 815      1500.0
# 816        95.0
# 817         0.0
# 818       385.0
# 819      1000.0
# 820       679.0
# 821       445.0
# 822       489.0
# 823      1200.0
# 824      4500.0
# 825       130.0
# 826       184.0
# 827         0.0
# 828      1500.0
# 829       518.0
# 830        41.0
# 831        70.0
# ...

# %% [markdown]
# # Google Play Store

# %%
#run this cell to load the data
import pandas as pd
apps=pd.read_csv("C:\\Users\\Omkar\\Downloads\\Datasets\\googleplaystore.csv")
apps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
len(np.unique(apps.get("App")))
# Out:
# 9660

# %% [markdown]
# Question 4.1. Assign by_content to a dataframe which counts the number of apps per Content Rating. List the Content Ratings alphabetically.
# Hint:You can use groupby

# %%
apps.dropna(inplace=True)
apps.isnull().sum()
content_rating=apps.groupby("Content Rating")
content_rating.groups
content_rating["Content Rating"].count()
# Out:
# Content Rating
# Adults only 18+       3
# Everyone           7414
# Everyone 10+        397
# Mature 17+          461
# Teen               1084
# Unrated               1
# Name: Content Rating, dtype: int64

# %% [markdown]
# Question 4.2. Compute the number of apps in the dataset that have 1.5 stars or lower, and save the result in bad_apps and compute the number of apps in the dataset that have 4 stars or higher, and save the results in good_apps.

# %%
apps["Good_app"]=apps["Rating"].apply(lambda x:x>2.5)
apps["Bad_app"]=apps["Rating"].apply(lambda x:x<2.5)
apps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
#Good_apps=
G=apps.groupby("Good_app")["App"]
G.groups
G.get_group(True)
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
# 5                               Paper flowers instructions
# 6                  Smoke Effect Photo Maker - Smoke Editor
# 7                                         Infinite Painter
# 8                                     Garden Coloring Book
# 9                            Kids Paint Free - Drawing Fun
# 10                                 Text on Photo - Fonteee
# 11                 Name Art Photo Editor - Focus n Filters
# 12                          Tattoo Name On My Photo Editor
# 13                                   Mandala Coloring Book
# 14         3D Color Pixel by Number - Sandbox Art Coloring
# 16            Photo Designer - Write your name with shapes
# ...

# %%
#Bad_apps=
G.get_group(False)
# Out:
# 518                         Just She - Top Lesbian Dating
# 520        EliteSingles – Dating for Single Professionals
# 527                                Sugar Daddy Dating App
# 549        EliteSingles – Dating for Single Professionals
# 554                         Just She - Top Lesbian Dating
# 625                               House party - live chat
# 663                         Just She - Top Lesbian Dating
# 2260                                             VeinSeek
# 2403         5 Minute Veterinary Consult: Canine & Feline
# 2492                                    mobileRx Pharmacy
# 3972                               Air Transat CinePlus B
# 4006                                              C by GE
# 4010                          Bridge-C - Get More Storage
# 4127                                    Speech Therapy: F
# 4161                                          G-Playlists
# 4253                                        J - Style Pro
# ...

# %% [markdown]
# Question 4.3. How many apps listed have the word "Google" (with that exact capitalization) in the App name? Save the number as google_apps.
#
# Note: each row is a separate App and should be counted as such (even if the names are the same).

# %% [markdown]
# Question 4.4. Of the apps under the Category COMMUNICATION, get the Content Rating count for apps where the Rating is between or equal to 4 and 5 (inclusive). Return this as a table sorted by count (with greatest count at the top of the table) called top_communication_apps.

# %%
apps["App"].unique()
G=apps.groupby("Category")
G.groups
A=G.get_group("COMMUNICATION")
A["Top_Communication_apps"]=apps["Rating"].apply(lambda x:(x>=4)and(x<=5))
H=A.groupby("Top_Communication_apps")["Rating"]
H.groups
p=H.get_group(True)
p.count()
# Out:
# C:\Users\Omkar\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# 268

# %% [markdown]
# Question 4.5. Create a table named install_stats which has a single column, Installs, which contains the mean number of install of apps in each type of content rating.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
apps=pd.read_csv("C:\\Users\\Omkar\\Downloads\\Datasets\\googleplaystore.csv")
apps.dropna(inplace=True)
apps.isnull().sum()
apps
apps["install_stats"]=apps["Installs"].apply(lambda x:float(x.split("+")[0].replace(",","")))
n=apps.loc[:,["Category","install_stats"]]
M=n.groupby("Category")
M.groups
M["install_stats"].mean()
# Out:
# Category
# ART_AND_DESIGN         2.036526e+06
# AUTO_AND_VEHICLES      7.278055e+05
# BEAUTY                 6.408619e+05
# BOOKS_AND_REFERENCE    1.079377e+07
# BUSINESS               3.306165e+06
# COMICS                 9.661397e+05
# COMMUNICATION          9.953427e+07
# DATING                 1.355360e+06
# EDUCATION              5.621626e+06
# ENTERTAINMENT          1.925611e+07
# EVENTS                 3.544313e+05
# FAMILY                 5.874944e+06
# FINANCE                2.713970e+06
# FOOD_AND_DRINK         2.511722e+06
# GAME                   3.198347e+07
# HEALTH_AND_FITNESS     5.330156e+06
# HOUSE_AND_HOME         2.218184e+06
# LIBRARIES_AND_DEMO     9.544219e+05
# LIFESTYLE              1.711978e+06
# MAPS_AND_NAVIGATION    5.840867e+06
# MEDICAL                1.520159e+05
# NEWS_AND_MAGAZINES     3.217258e+07
# PARENTING              6.223222e+05
# PERSONALIZATION        7.453019e+06
# PHOTOGRAPHY            3.182411e+07
# PRODUCTIVITY           4.038766e+07
# ...

# %% [markdown]
# Question4.6. Suppose a good app is one with at least one million installs and a rating of at least 4.0. Create a variable called best_category containing the name of the category with the most good apps.

# %%
apps["Best_Category"]=apps["Rating"].apply(lambda x:x>4)
apps["Best_Category"]=apps["install_stats"].apply(lambda x:x>1000000)
apps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %% [markdown]
# Question 4.7. Make a bar chart of the average rating by category in which the bars are sorted from smallest to largest.

# %%
import seaborn as sns
x=apps["Rating"]
y=apps["Category"]
sns.barplot(x,y)
# Out:
# C:\Users\Omkar\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # 5. Histograms

# %% [markdown]
# Question 5.1. Make a histogram of the pay of the CEOs in compensation

# %%
new_df_compensation.columns
# Out:
# Index(['Name', 'Company (Headquarters)', 'Total Pay', '% Change', 'Cash Pay',
#        'Equity Pay', 'Other Pay',
#        'Ratio of CEO pay to average industry worker pay', 'ToTal_Pay_Dollars'],
#       dtype='object')

# %%
sns.histplot(x='ToTal_Pay_Dollars',data=new_df_compensation)

# %% [markdown]
# Question 5.2. Looking at the histogram, about how many CEOs made more than $30 million? Make a good guess. (Answer the question by filling in your answer manually. You'll have to do a bit of arithmetic; feel free to use Python as a calculator.)

# %%
num_ceos_more_than_30_million =  8

# %%
o=new_df_compensation['ToTal_Pay_Dollars']>30000000
o.sum()
# Out:
# 5

# %% [markdown]
# Question 5.3. Answer the same question with code.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
new_df_compensation['ToTal_Pay_Dollars']=le.fit_transform(new_df_compensation['ToTal_Pay_Dollars']>30000000)

# %%
A=new_df_compensation['ToTal_Pay_Dollars']
A.sum()
# Out:
# 5

# %% [markdown]
# # Finish Line
