# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\Krishna\\Desktop\\dataset\\temperature.csv",parse_dates=["datetime"],index_col="datetime")
df
# Out:
#                       Vancouver    Portland  San Francisco     Seattle  \
# datetime
# 2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
# ...                         ...         ...            ...         ...
# 2017-11-29 20:00:00         NaN  282.000000            NaN  280.820000
# 2017-11-29 21:00:00         NaN  282.890000            NaN  281.650000
# 2017-11-29 22:00:00         NaN  283.390000            NaN  282.750000
# 2017-11-29 23:00:00         NaN  283.020000            NaN  282.960000
# 2017-11-30 00:00:00         NaN  282.280000            NaN  283.040000
#
#                      Los Angeles   San Diego   Las Vegas     Phoenix  \
# datetime
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45253 entries, 2012-10-01 12:00:00 to 2017-11-30 00:00:00
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Vancouver          44458 non-null  float64
#  1   Portland           45252 non-null  float64
#  2   San Francisco      44460 non-null  float64
#  3   Seattle            45250 non-null  float64
#  4   Los Angeles        45250 non-null  float64
#  5   San Diego          45252 non-null  float64
#  6   Las Vegas          45252 non-null  float64
#  7   Phoenix            45250 non-null  float64
#  8   Albuquerque        45252 non-null  float64
#  9   Denver             45252 non-null  float64
#  10  San Antonio        45252 non-null  float64
#  11  Dallas             45249 non-null  float64
#  12  Houston            45250 non-null  float64
#  13  Kansas City        45252 non-null  float64
#  14  Minneapolis        45240 non-null  float64
# ...

# %% [markdown]
# ## Data Cleaning

# %%
df.isna().sum()
# Out:
# Vancouver            795
# Portland               1
# San Francisco        793
# Seattle                3
# Los Angeles            3
# San Diego              1
# Las Vegas              1
# Phoenix                3
# Albuquerque            1
# Denver                 1
# San Antonio            1
# Dallas                 4
# Houston                3
# Kansas City            1
# Minneapolis           13
# Saint Louis            1
# Chicago                3
# Nashville              2
# Indianapolis           7
# Atlanta                6
# Detroit                1
# Jacksonville           1
# Charlotte              3
# Miami                805
# Pittsburgh             3
# Toronto                1
# Philadelphia           3
# New York             793
# Montreal               3
# Boston                 3
# Beersheba            798
# Tel Aviv District    793
# Eilat                792
# Haifa                798
# Nahariyya            797
# Jerusalem            793
# dtype: int64

# %%
df["Vancouver"]=df["Vancouver"].fillna(df["Vancouver"].median())
df["Portland"]=df["Portland"].fillna(df["Portland"].median())
df["San Francisco"]=df["San Francisco"].fillna(df["San Francisco"].median())
df["Seattle"]=df["Seattle"].fillna(df["Seattle"].median())
df["Los Angeles"]=df["Los Angeles"].fillna(df["Los Angeles"].median())
df["San Diego"]=df["San Diego"].fillna(df["San Diego"].median())
df["Las Vegas"]=df["Las Vegas"].fillna(df["Las Vegas"].median())
df["Phoenix"]=df["Phoenix"].fillna(df["Phoenix"].median())
df["Albuquerque"]=df["Albuquerque"].fillna(df["Albuquerque"].median())
df["Denver"]=df["Denver"].fillna(df["Denver"].median())
df["San Antonio"]=df["San Antonio"].fillna(df["San Antonio"].median())
df["Dallas"]=df["Dallas"].fillna(df["Dallas"].median())
df["Houston"]=df["Houston"].fillna(df["Houston"].median())
df["Kansas City"]=df["Kansas City"].fillna(df["Kansas City"].median())
df["Minneapolis"]=df["Minneapolis"].fillna(df["Minneapolis"].median())
df["Saint Louis"]=df["Saint Louis"].fillna(df["Saint Louis"].median())
df["Chicago"]=df["Chicago"].fillna(df["Chicago"].median())
df["Nashville"]=df["Nashville"].fillna(df["Nashville"].median())
df["Indianapolis"]=df["Indianapolis"].fillna(df["Indianapolis"].median())
df["Atlanta"]=df["Atlanta"].fillna(df["Atlanta"].median())
df["Detroit"]=df["Detroit"].fillna(df["Detroit"].median())
df["Jacksonville"]=df["Jacksonville"].fillna(df["Jacksonville"].median())
df["Charlotte"]=df["Charlotte"].fillna(df["Charlotte"].median())
df["Miami"]=df["Miami"].fillna(df["Miami"].median())
df["Pittsburgh"]=df["Pittsburgh"].fillna(df["Pittsburgh"].median())
df["Toronto"]=df["Toronto"].fillna(df["Toronto"].median())
df["Philadelphia"]=df["Philadelphia"].fillna(df["Philadelphia"].median())
df["New York"]=df["New York"].fillna(df["New York"].median())
df["Montreal"]=df["Montreal"].fillna(df["Montreal"].median())
df["Boston"]=df["Boston"].fillna(df["Boston"].median())
df["Beersheba"]=df["Beersheba"].fillna(df["Beersheba"].median())
df["Tel Aviv District"]=df["Tel Aviv District"].fillna(df["Tel Aviv District"].median())
df["Jacksonville"]=df["Jacksonville"].fillna(df["Jacksonville"].median())
df["Eilat"]=df["Eilat"].fillna(df["Eilat"].median())
df["Haifa"]=df["Haifa"].fillna(df["Haifa"].median())
df["Nahariyya"]=df["Nahariyya"].fillna(df["Nahariyya"].median())
df["Jerusalem"]=df["Jerusalem"].fillna(df["Jerusalem"].median())

# %%
df.isna().sum()
# Out:
# Vancouver            0
# Portland             0
# San Francisco        0
# Seattle              0
# Los Angeles          0
# San Diego            0
# Las Vegas            0
# Phoenix              0
# Albuquerque          0
# Denver               0
# San Antonio          0
# Dallas               0
# Houston              0
# Kansas City          0
# Minneapolis          0
# Saint Louis          0
# Chicago              0
# Nashville            0
# Indianapolis         0
# Atlanta              0
# Detroit              0
# Jacksonville         0
# Charlotte            0
# Miami                0
# Pittsburgh           0
# Toronto              0
# Philadelphia         0
# New York             0
# Montreal             0
# Boston               0
# Beersheba            0
# Tel Aviv District    0
# Eilat                0
# Haifa                0
# Nahariyya            0
# Jerusalem            0
# dtype: int64

# %%
df.describe()
# Out:
#           Vancouver      Portland  San Francisco       Seattle   Los Angeles  \
# count  45253.000000  45253.000000   45253.000000  45253.000000  45253.000000
# mean     283.855404    284.992914     288.146256    284.409595    290.846095
# std        6.581768      7.452357       5.286414      6.547770      6.460610
# min      245.150000    262.370000     272.300000    263.780000    266.503667
# 25%      279.244000    279.850000     284.740000    279.830000    286.380000
# 50%      283.450000    284.320000     287.610000    283.940000    290.530000
# 75%      288.510000    289.450000     290.930000    288.530000    295.080000
# max      307.000000    312.520000     313.620000    307.300000    315.470000
#
#           San Diego     Las Vegas       Phoenix   Albuquerque        Denver  \
# count  45253.000000  45253.000000  45253.000000  45253.000000  45253.000000
# mean     290.215042    292.424878    295.493364    285.617867    282.839410
# ...

# %%
df.shape
# Out:
# (45253, 36)

# %% [markdown]
# ## Data visualization

# %%
year=df.resample("Y").mean()

# %%
year.head(10)
# Out:
#              Vancouver    Portland  San Francisco     Seattle  Los Angeles  \
# datetime
# 2012-12-31  280.409557  281.824578     286.519456  281.204316   289.572399
# 2013-12-31  283.407060  284.256730     287.236179  283.678395   290.320935
# 2014-12-31  284.092337  284.983545     288.177642  284.712229   290.393276
# 2015-12-31  284.399065  285.357114     288.073482  285.105857   290.340005
# 2016-12-31  284.100439  285.504560     288.395490  284.730342   291.477787
# 2017-12-31  284.168703  285.719053     289.362069  284.644343   292.128304
#
#              San Diego   Las Vegas     Phoenix  Albuquerque      Denver  ...  \
# datetime                                                                 ...
# 2012-12-31  289.306048  287.878220  291.409716   280.721029  278.875088  ...
# 2013-12-31  289.441932  292.624686  295.307527   285.052539  282.250008  ...
# 2014-12-31  290.148077  291.507119  294.809901   285.942909  281.523557  ...
# ...

# %%
df['Vancouver'].plot()

# %%
df_year = df.resample("Y").mean()
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(df_year['2013':].index, df_year.loc['2017':, "Vancouver"], width=25, align='center')
# Out:
# <BarContainer object of 5 artists>

# %%
df_year['Vancouver'].plot(figsize=(8, 6))

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
plt.plot(df['Boston'],label='temperature')
plt.plot(df['Vancouver'],label='temperature')
plt.plot(df['Portland'],label='temperature')

# %%
month = df.resample("M").mean()

# %%
month
# Out:
#              Vancouver    Portland  San Francisco     Seattle  Los Angeles  \
# datetime
# 2012-10-31  283.294000  285.209441     289.614498  284.329433   293.251431
# 2012-11-30  280.393083  281.761056     286.592826  281.012396   289.276347
# 2012-12-31  277.587581  278.555784     283.403330  278.315333   286.239209
# 2013-01-31  275.034871  275.151107     281.394927  275.973781   284.742942
# 2013-02-28  278.289115  278.971179     283.198898  279.159787   285.734333
# ...                ...         ...            ...         ...          ...
# 2017-07-31  291.404683  293.195441     293.333237  291.504130   296.950910
# 2017-08-31  292.127786  295.082134     292.339323  293.105609   296.795788
# 2017-09-30  289.332272  291.546095     293.819971  289.980499   295.890822
# 2017-10-31  283.425305  284.733027     289.897980  283.497866   294.827879
# 2017-11-30  283.450000  281.449961     287.610000  280.612317   290.982388
#
# ...

# %%
fig=plt.figure(figsize=(20,10))
plt.plot(df.loc['2012-10-31':'2017-11-30', 'Vancouver'], marker='.', linestyle='-', linewidth = 0.5, label='Daily', color='black')
plt.plot(month.loc['2012-10-31':'2017-11-30', 'Vancouver'], marker='o', markersize=8, linestyle='-', label='Weekly', color='coral')
plt.legend()

# %%
weekly = df.resample("W").mean()

# %%
weekly
# Out:
#              Vancouver    Portland  San Francisco     Seattle  Los Angeles  \
# datetime
# 2012-10-07  284.998032  287.416991     292.373413  285.355514   294.617098
# 2012-10-14  284.720833  285.642262     288.176220  286.034792   291.513393
# 2012-10-21  283.916726  285.731905     291.387708  285.012708   294.941369
# 2012-10-28  279.670387  281.088631     287.071310  280.389077   292.391905
# 2012-11-04  283.856786  286.729613     288.123899  285.597649   290.684137
# ...                ...         ...            ...         ...          ...
# 2017-11-05  283.450000  282.027857     287.610000  279.607857   290.931964
# 2017-11-12  283.450000  280.658369     287.610000  279.485380   290.270946
# 2017-11-19  283.450000  281.176827     287.610000  281.013458   290.806239
# 2017-11-26  283.450000  283.204643     287.610000  282.956131   292.999821
# 2017-12-03  283.450000  279.988219     287.610000  279.785616   288.786808
#
# ...

# %%
fig=plt.figure(figsize=(20,10))
plt.plot(df.loc['2012-10-07':'2017-12-03', 'Vancouver'], marker='.', linestyle='-', linewidth = 0.5, label='Daily', color='black')
plt.plot(weekly.loc['2012-10-07':'2017-12-03', 'Vancouver'], marker='o', markersize=8, linestyle='-', label='Weekly', color='coral')
plt.legend()

# %%
from pylab import rcParams
import statsmodels.api as sm
rcParams['figure.figsize'] = 11, 9
decomposition = sm.tsa.seasonal_decompose(month['Vancouver'], model='Additive')
fig = decomposition.plot()

# %%
from pylab import rcParams
import statsmodels.api as sm
rcParams['figure.figsize'] = 11, 9
decomposition = sm.tsa.seasonal_decompose(weekly['Vancouver'], model='Additive')
fig = decomposition.plot()

# %%
day=df.resample("D").mean()

# %%
day
# Out:
#              Vancouver    Portland  San Francisco     Seattle  Los Angeles  \
# datetime
# 2012-10-01  284.523205  282.301681     289.266089  281.948324   291.736792
# 2012-10-02  286.145190  286.137728     292.958306  285.156888   295.890450
# 2012-10-03  285.528125  289.599792     296.929167  287.673958   299.008542
# 2012-10-04  284.373333  286.482500     295.687083  284.391667   295.997917
# 2012-10-05  283.757292  288.286042     290.635417  284.756250   292.948333
# ...                ...         ...            ...         ...          ...
# 2017-11-26  283.450000  281.588333     287.610000  282.576667   290.424167
# 2017-11-27  283.450000  279.922500     287.610000  279.854167   289.364583
# 2017-11-28  283.450000  280.085833     287.610000  280.094167   287.512792
# 2017-11-29  283.450000  279.860833     287.610000  279.272917   289.227083
# 2017-11-30  283.450000  282.280000     287.610000  283.040000   294.930000
#
# ...

# %%
from pylab import rcParams
import statsmodels.api as sm
rcParams['figure.figsize'] = 11, 9
decomposition = sm.tsa.seasonal_decompose(day['Vancouver'], model='Additive')
fig = decomposition.plot()

# %%
from statsmodels.tsa.stattools import adfuller
res=adfuller(df["Vancouver"])
res
# Out:
# (-6.051951942518948,
#  1.2713523973738567e-07,
#  54,
#  45198,
#  {'1%': -3.430494689398358,
#   '5%': -2.861603949592821,
#   '10%': -2.5668040382793214},
#  106813.54020067968)

# %%
pval=res[1]
pval
# Out:
# 1.2713523973738567e-07

# %%
if pval<0.05:
    print(" it is stationary")
else:
    print("It is not stationary")
# Out:
#  it is stationary

# %%
day.Vancouver.plot()
