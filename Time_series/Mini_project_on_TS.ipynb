# %% [markdown]
# ## Project Name:- Stock Volume Prediction
# ### Student Name: ML_06
# #### 1) Nitin Borse
# #### 2) Asharaf ALi
# #### 3) Tejal Survade
# #### 4) Rashmi Patil
#
# #### Guided by
# #### Ankita Kanchan

# %% [markdown]
# ##  Using Arima model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pmdarima import auto_arima
import warnings                   # To ignore the warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("C:\\Users\\Krishna\\Desktop\\dataset\\TCS.NS.csv",index_col='Date', parse_dates=['Date'])
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-04-27  1832.300049  1875.000000  1825.000000  1836.599976  1815.905884
# 2020-04-28  1865.000000  1868.000000  1832.599976  1859.050049  1838.102905
# 2020-04-29  1874.000000  1912.550049  1850.050049  1905.650024  1884.177979
# 2020-04-30  1980.000000  2032.000000  1942.199951  2014.449951  1991.751831
# 2020-05-04  1966.000000  1966.000000  1913.650024  1930.449951  1908.698364
# ...                 ...          ...          ...          ...          ...
# 2021-04-20  3225.000000  3225.350098  3126.350098  3144.550049  3144.550049
# 2021-04-22  3148.000000  3148.000000  3105.250000  3118.800049  3118.800049
# 2021-04-23  3105.000000  3119.000000  3091.050049  3109.500000  3109.500000
# 2021-04-26  3102.050049  3153.000000  3088.050049  3100.800049  3100.800049
# 2021-04-27  3106.000000  3133.500000  3103.000000  3119.899902  3119.899902
#
#                Volume
# Date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2020-04-27 to 2021-04-27
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       250 non-null    float64
#  1   High       250 non-null    float64
#  2   Low        250 non-null    float64
#  3   Close      250 non-null    float64
#  4   Adj Close  250 non-null    float64
#  5   Volume     250 non-null    float64
# dtypes: float64(6)
# memory usage: 13.7 KB

# %%
df.isna().sum()
# Out:
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.shape
# Out:
# (250, 6)

# %%
df["Volume"].plot()

# %%
df=df.head(100)

# %%
from statsmodels.tsa.stattools import adfuller
res=adfuller(df.Volume)
pval=res[1]
if pval>0.05:
  print("Not Stationary")
else:
  print("Stationary")
# Out:
# Stationary

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model=ARIMA(df.Volume,order=(3,1,2))
m=model.fit(disp=0)

# %%
m.plot_predict(dynamic=False)

# %%
m.resid
# Out:
# Date
# 2020-04-28   -7.360747e+05
# 2020-04-29    1.297078e+06
# 2020-04-30    1.998600e+06
# 2020-05-04   -8.171942e+05
# 2020-05-05   -8.093158e+05
#                   ...
# 2020-09-09   -1.568707e+06
# 2020-09-10   -1.631445e+06
# 2020-09-11    7.504894e+03
# 2020-09-14    2.840808e+06
# 2020-09-15    1.815464e+06
# Length: 99, dtype: float64

# %%
m.resid.plot()

# %%
m.resid.plot(kind="hist")

# %%
m.resid.plot(kind="kde")

# %% [markdown]
# ## Using Auto_Arima Model

# %%
df=pd.read_csv("C:\\Users\\Krishna\\Desktop\\dataset\\TCS.NS.csv",index_col="Date", parse_dates=['Date'])
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-04-27  1832.300049  1875.000000  1825.000000  1836.599976  1815.905884
# 2020-04-28  1865.000000  1868.000000  1832.599976  1859.050049  1838.102905
# 2020-04-29  1874.000000  1912.550049  1850.050049  1905.650024  1884.177979
# 2020-04-30  1980.000000  2032.000000  1942.199951  2014.449951  1991.751831
# 2020-05-04  1966.000000  1966.000000  1913.650024  1930.449951  1908.698364
# ...                 ...          ...          ...          ...          ...
# 2021-04-20  3225.000000  3225.350098  3126.350098  3144.550049  3144.550049
# 2021-04-22  3148.000000  3148.000000  3105.250000  3118.800049  3118.800049
# 2021-04-23  3105.000000  3119.000000  3091.050049  3109.500000  3109.500000
# 2021-04-26  3102.050049  3153.000000  3088.050049  3100.800049  3100.800049
# 2021-04-27  3106.000000  3133.500000  3103.000000  3119.899902  3119.899902
#
#                Volume
# Date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2020-04-27 to 2021-04-27
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       250 non-null    float64
#  1   High       250 non-null    float64
#  2   Low        250 non-null    float64
#  3   Close      250 non-null    float64
#  4   Adj Close  250 non-null    float64
#  5   Volume     250 non-null    float64
# dtypes: float64(6)
# memory usage: 13.7 KB

# %%
df=df.dropna()

# %%
df["Volume"].plot()

# %%
from statsmodels.tsa.stattools import adfuller
res=adfuller(df.Volume)
pval=res[1]
if pval<0.05:
    print(" it is stationary")
else:
    print("It is not stationary")
# Out:
#  it is stationary

# %%
plt.plot(df.index,df.Volume)

# %%
from pmdarima import auto_arima

# %%
auto_model=auto_arima(df["Volume"].dropna(),Trace=True)

# %%
auto_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  250
# Model:               SARIMAX(5, 0, 0)   Log Likelihood               -3953.616
# Date:                Sat, 01 May 2021   AIC                           7921.233
# Time:                        22:28:11   BIC                           7945.883
# Sample:                             0   HQIC                          7931.154
#                                 - 250
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   1.407e+06   6.85e-09   2.05e+14      0.000    1.41e+06    1.41e+06
# ar.L1          0.4145      0.064      6.436      0.000       0.288       0.541
# ar.L2         -0.0423      0.060     -0.700      0.484      -0.161       0.076
# ...

# %% [markdown]
# ## Using Auto_Regression_Model

# %%
df=pd.read_csv("C:\\Users\\Krishna\\Desktop\\dataset\\TCS.NS.csv",parse_dates=['Date'])
df
# Out:
#           Date         Open         High          Low        Close  \
# 0   2020-04-27  1832.300049  1875.000000  1825.000000  1836.599976
# 1   2020-04-28  1865.000000  1868.000000  1832.599976  1859.050049
# 2   2020-04-29  1874.000000  1912.550049  1850.050049  1905.650024
# 3   2020-04-30  1980.000000  2032.000000  1942.199951  2014.449951
# 4   2020-05-04  1966.000000  1966.000000  1913.650024  1930.449951
# ..         ...          ...          ...          ...          ...
# 246 2021-04-20  3225.000000  3225.350098  3126.350098  3144.550049
# 247 2021-04-22  3148.000000  3148.000000  3105.250000  3118.800049
# 248 2021-04-23  3105.000000  3119.000000  3091.050049  3109.500000
# 249 2021-04-26  3102.050049  3153.000000  3088.050049  3100.800049
# 250 2021-04-27  3106.000000  3133.500000  3103.000000  3119.899902
#
#        Adj Close     Volume
# 0    1815.905884  3374741.0
# 1    1838.102905  2678505.0
# 2    1884.177979  4241510.0
# 3    1991.751831  5915544.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    datetime64[ns]
#  1   Open       250 non-null    float64
#  2   High       250 non-null    float64
#  3   Low        250 non-null    float64
#  4   Close      250 non-null    float64
#  5   Adj Close  250 non-null    float64
#  6   Volume     250 non-null    float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 13.9 KB

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.plot(x="Date",y="Volume")

# %%
pd.plotting.lag_plot(df.Volume)

# %%
pd.plotting.autocorrelation_plot(df.Volume)

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(df.Volume)

# %%
df["Volume_diff"]=df.Volume.diff()

# %%
df.plot(x="Date",y="Volume_diff")

# %%
plot_acf(df.Volume_diff.dropna())

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df=df.set_index("Date")
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-04-27  1832.300049  1875.000000  1825.000000  1836.599976  1815.905884
# 2020-04-28  1865.000000  1868.000000  1832.599976  1859.050049  1838.102905
# 2020-04-29  1874.000000  1912.550049  1850.050049  1905.650024  1884.177979
# 2020-04-30  1980.000000  2032.000000  1942.199951  2014.449951  1991.751831
# 2020-05-04  1966.000000  1966.000000  1913.650024  1930.449951  1908.698364
# ...                 ...          ...          ...          ...          ...
# 2021-04-20  3225.000000  3225.350098  3126.350098  3144.550049  3144.550049
# 2021-04-22  3148.000000  3148.000000  3105.250000  3118.800049  3118.800049
# 2021-04-23  3105.000000  3119.000000  3091.050049  3109.500000  3109.500000
# 2021-04-26  3102.050049  3153.000000  3088.050049  3100.800049  3100.800049
# 2021-04-27  3106.000000  3133.500000  3103.000000  3119.899902  3119.899902
#
#                Volume  Volume_diff
# Date
# ...

# %%
#dec=seasonal_decompose(df.Volume_diff.dropna())
#fig=dec.plot()

# %%
from statsmodels.tsa.ar_model import AR

# %%
model=AR(df.Volume_diff.dropna())
m=model.fit()

# %%
m.k_ar
# Out:
# 15

# %%
m.params
# Out:
# const             -13224.051991
# L1.Volume_diff        -0.560507
# L2.Volume_diff        -0.579151
# L3.Volume_diff        -0.214261
# L4.Volume_diff        -0.362447
# L5.Volume_diff        -0.297471
# L6.Volume_diff        -0.294591
# L7.Volume_diff        -0.239196
# L8.Volume_diff        -0.067021
# L9.Volume_diff        -0.094051
# L10.Volume_diff        0.007030
# L11.Volume_diff       -0.114512
# L12.Volume_diff       -0.121400
# L13.Volume_diff       -0.105230
# L14.Volume_diff       -0.008497
# L15.Volume_diff        0.024942
# dtype: float64

# %%
prediction=m.predict(dynamic=False)

# %%
plt.plot(df.Volume_diff)
plt.plot(prediction)

# %% [markdown]
# ## Using Moving Average

# %%
df=pd.read_csv("C:\\Users\\Krishna\\Desktop\\dataset\\TCS.NS.csv",parse_dates=['Date'])
df
# Out:
#           Date         Open         High          Low        Close  \
# 0   2020-04-27  1832.300049  1875.000000  1825.000000  1836.599976
# 1   2020-04-28  1865.000000  1868.000000  1832.599976  1859.050049
# 2   2020-04-29  1874.000000  1912.550049  1850.050049  1905.650024
# 3   2020-04-30  1980.000000  2032.000000  1942.199951  2014.449951
# 4   2020-05-04  1966.000000  1966.000000  1913.650024  1930.449951
# ..         ...          ...          ...          ...          ...
# 246 2021-04-20  3225.000000  3225.350098  3126.350098  3144.550049
# 247 2021-04-22  3148.000000  3148.000000  3105.250000  3118.800049
# 248 2021-04-23  3105.000000  3119.000000  3091.050049  3109.500000
# 249 2021-04-26  3102.050049  3153.000000  3088.050049  3100.800049
# 250 2021-04-27  3106.000000  3133.500000  3103.000000  3119.899902
#
#        Adj Close     Volume
# 0    1815.905884  3374741.0
# 1    1838.102905  2678505.0
# 2    1884.177979  4241510.0
# 3    1991.751831  5915544.0
# ...

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       250 non-null    datetime64[ns]
#  1   Open       250 non-null    float64
#  2   High       250 non-null    float64
#  3   Low        250 non-null    float64
#  4   Close      250 non-null    float64
#  5   Adj Close  250 non-null    float64
#  6   Volume     250 non-null    float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 15.6 KB

# %% [markdown]
# ### Simple Moving Average Technique

# %%
df["SMA2"]=df["Volume"].rolling(window=2).mean()

# %%
df
# Out:
#           Date         Open         High          Low        Close  \
# 0   2020-04-27  1832.300049  1875.000000  1825.000000  1836.599976
# 1   2020-04-28  1865.000000  1868.000000  1832.599976  1859.050049
# 2   2020-04-29  1874.000000  1912.550049  1850.050049  1905.650024
# 3   2020-04-30  1980.000000  2032.000000  1942.199951  2014.449951
# 4   2020-05-04  1966.000000  1966.000000  1913.650024  1930.449951
# ..         ...          ...          ...          ...          ...
# 246 2021-04-20  3225.000000  3225.350098  3126.350098  3144.550049
# 247 2021-04-22  3148.000000  3148.000000  3105.250000  3118.800049
# 248 2021-04-23  3105.000000  3119.000000  3091.050049  3109.500000
# 249 2021-04-26  3102.050049  3153.000000  3088.050049  3100.800049
# 250 2021-04-27  3106.000000  3133.500000  3103.000000  3119.899902
#
#        Adj Close     Volume       SMA2
# 0    1815.905884  3374741.0        NaN
# 1    1838.102905  2678505.0  3026623.0
# 2    1884.177979  4241510.0  3460007.5
# ...

# %%
df["SMA4"]=df["Volume"].rolling(window=4).mean()

# %%
df
# Out:
#           Date         Open         High          Low        Close  \
# 0   2020-04-27  1832.300049  1875.000000  1825.000000  1836.599976
# 1   2020-04-28  1865.000000  1868.000000  1832.599976  1859.050049
# 2   2020-04-29  1874.000000  1912.550049  1850.050049  1905.650024
# 3   2020-04-30  1980.000000  2032.000000  1942.199951  2014.449951
# 4   2020-05-04  1966.000000  1966.000000  1913.650024  1930.449951
# ..         ...          ...          ...          ...          ...
# 246 2021-04-20  3225.000000  3225.350098  3126.350098  3144.550049
# 247 2021-04-22  3148.000000  3148.000000  3105.250000  3118.800049
# 248 2021-04-23  3105.000000  3119.000000  3091.050049  3109.500000
# 249 2021-04-26  3102.050049  3153.000000  3088.050049  3100.800049
# 250 2021-04-27  3106.000000  3133.500000  3103.000000  3119.899902
#
#        Adj Close     Volume       SMA2        SMA4
# 0    1815.905884  3374741.0        NaN         NaN
# 1    1838.102905  2678505.0  3026623.0         NaN
# ...

# %%
df["SMA7"]=df["Volume"].rolling(window=7).mean()

# %%
df
# Out:
#           Date         Open         High          Low        Close  \
# 0   2020-04-27  1832.300049  1875.000000  1825.000000  1836.599976
# 1   2020-04-28  1865.000000  1868.000000  1832.599976  1859.050049
# 2   2020-04-29  1874.000000  1912.550049  1850.050049  1905.650024
# 3   2020-04-30  1980.000000  2032.000000  1942.199951  2014.449951
# 4   2020-05-04  1966.000000  1966.000000  1913.650024  1930.449951
# ..         ...          ...          ...          ...          ...
# 246 2021-04-20  3225.000000  3225.350098  3126.350098  3144.550049
# 247 2021-04-22  3148.000000  3148.000000  3105.250000  3118.800049
# 248 2021-04-23  3105.000000  3119.000000  3091.050049  3109.500000
# 249 2021-04-26  3102.050049  3153.000000  3088.050049  3100.800049
# 250 2021-04-27  3106.000000  3133.500000  3103.000000  3119.899902
#
#        Adj Close     Volume       SMA2        SMA4          SMA7
# 0    1815.905884  3374741.0        NaN         NaN           NaN
# ...

# %%
p_df=df.head(100)
p_df
# Out:
#          Date         Open         High          Low        Close  \
# 0  2020-04-27  1832.300049  1875.000000  1825.000000  1836.599976
# 1  2020-04-28  1865.000000  1868.000000  1832.599976  1859.050049
# 2  2020-04-29  1874.000000  1912.550049  1850.050049  1905.650024
# 3  2020-04-30  1980.000000  2032.000000  1942.199951  2014.449951
# 4  2020-05-04  1966.000000  1966.000000  1913.650024  1930.449951
# ..        ...          ...          ...          ...          ...
# 95 2020-09-09  2325.000000  2359.000000  2320.000000  2327.649902
# 96 2020-09-10  2335.000000  2348.500000  2324.300049  2331.149902
# 97 2020-09-11  2330.949951  2383.000000  2330.149902  2374.100098
# 98 2020-09-14  2384.100098  2505.750000  2381.850098  2491.399902
# 99 2020-09-15  2491.399902  2538.000000  2464.600098  2491.399902
#
#       Adj Close     Volume       SMA2        SMA4          SMA7
# 0   1815.905884  3374741.0        NaN         NaN           NaN
# ...

# %%
fig=plt.figure(figsize=(10,5))
plt.plot(p_df["Volume"],label="Original")
plt.plot(p_df["SMA2"],label="SMA2")
plt.plot(p_df["SMA4"],label="SMA4")
plt.plot(p_df["SMA7"],label="SMA7")
plt.legend()

# %% [markdown]
# ## Commulative Moving Average Technique

# %%
df["CMA"]=df["Volume"].expanding(min_periods=5).mean()

# %%
df=df.head(100)

# %%
df["CMA3"]=df["Volume"].expanding(min_periods=3).mean()

# %%
fig=plt.figure(figsize=(10,5))
plt.plot(df["Volume"],label="Original")
plt.plot(df["CMA"],label="CMA")
plt.plot(df["CMA3"],label="CMA3")
plt.legend()

# %%
#Exponential Moving Avarege

# Exponential Weighted a function
# 2 adjust-- True 
# Com,span,halflife--alpha
# directly can use alpha if its given or you can do a trail error to see the smoothing effect

# %%
df["EMA"]=df["Volume"].ewm(com=0.5,adjust=True).mean()

# %%
df.head()
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0 2020-04-27  1832.300049  1875.000000  1825.000000  1836.599976  1815.905884
# 1 2020-04-28  1865.000000  1868.000000  1832.599976  1859.050049  1838.102905
# 2 2020-04-29  1874.000000  1912.550049  1850.050049  1905.650024  1884.177979
# 3 2020-04-30  1980.000000  2032.000000  1942.199951  2014.449951  1991.751831
# 4 2020-05-04  1966.000000  1966.000000  1913.650024  1930.449951  1908.698364
#
#       Volume       SMA2        SMA4  SMA7        CMA          CMA3  \
# 0  3374741.0        NaN         NaN   NaN        NaN           NaN
# 1  2678505.0  3026623.0         NaN   NaN        NaN           NaN
# 2  4241510.0  3460007.5         NaN   NaN        NaN  3.431585e+06
# 3  5915544.0  5078527.0  4052575.00   NaN        NaN  4.052575e+06
# 4  3729348.0  4822446.0  4141226.75   NaN  3987929.6  3.987930e+06
#
#             EMA
# 0  3.374741e+06
# 1  2.852564e+06
# 2  3.814142e+06
# 3  5.232588e+06
# ...

# %%
fig=plt.figure(figsize=(10,5))
plt.plot(df["Volume"],label="Original")
plt.plot(df["EMA"],label="EMA")
plt.legend()

# %%
df["EMA1"]=df["Volume"].ewm(com=0.2,adjust=True).mean()

# %%
df_b=df.head(100)

# %%
fig=plt.figure(figsize=(10,5))
plt.plot(df_b["Volume"],label="Original")
plt.plot(df_b["CMA"],label="CMA")
plt.plot(df_b["EMA1"],label="EMA1")
plt.legend()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Here in this case Exponential Moving Avegare Technique Gives the best Prediction Result Show in above figure as compare to other Technique.
